# %%
import gensim
import MeCab
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import argparse

# %%
class args:
    faq = ""
    model = ""
    dictionary = ""

# %%
mecab = MeCab.Tagger("-Owakati" + ("" if not args.dictionary else " -d " + args.dictionary))

model = gensim.models.Doc2Vec.load(args.model)
# Out:
# --------------------------------------------------------------------------
# RuntimeError                             Traceback (most recent call last)
# <ipython-input-4-4b8b6c79770a> in <module>()
#       1 mecab = MeCab.Tagger("-Owakati" + ("" if not args.dictionary else " -d " + args.dictionary))
#       2
# ----> 3 model = gensim.models.Doc2Vec.load(args.model)
#       4
#
# /opt/homebrew/var/pyenv/versions/anaconda3-4.1.1/lib/python3.6/site-packages/gensim/models/word2vec.py in load(cls, *args, **kwargs)
#    1518     @classmethod
#    1519     def load(cls, *args, **kwargs):
# -> 1520         model = super(Word2Vec, cls).load(*args, **kwargs)
#    1521         # update older models
#    1522         if hasattr(model, 'table'):
#
# /opt/homebrew/var/pyenv/versions/anaconda3-4.1.1/lib/python3.6/site-packages/gensim/utils.py in load(cls, fname, mmap)
#     278         compress, subname = SaveLoad._adapt_by_suffix(fname)
#     279
# --> 280         obj = unpickle(fname)
#     281         obj._load_specials(fname, mmap, compress, subname)
#     282         logger.info("loaded %s", fname)
#
# /opt/homebrew/var/pyenv/versions/anaconda3-4.1.1/lib/python3.6/site-packages/gensim/utils.py in unpickle(fname)
#     928 def unpickle(fname):
#     929     """Load pickled object from `fname`"""
# --> 930     with smart_open(fname, 'rb') as f:
#     931         # Because of loading from S3 load can't be used (missing readline in smart_open)
#     932         if sys.version_info > (3, 0):
#
# /opt/homebrew/var/pyenv/versions/anaconda3-4.1.1/lib/python3.6/site-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     133         # this method just routes the request to classes handling the specific storage
#     134         # schemes, depending on the URI protocol in `uri`
# --> 135         parsed_uri = ParseUri(uri)
#     136
#     137         if parsed_uri.scheme in ("file", ):
#
# /opt/homebrew/var/pyenv/versions/anaconda3-4.1.1/lib/python3.6/site-packages/smart_open/smart_open_lib.py in __init__(self, uri, default_scheme)
#     303
#     304             if not self.uri_path:
# --> 305                 raise RuntimeError("invalid file URI: %s" % uri)
#     306         elif self.scheme.startswith('http'):
#     307             self.uri_path = uri
#
# RuntimeError: invalid file URI:

# %%
questions = []
# answers = []
for line in open(args.faq, "r", encoding="utf-8"):
    cols = line.strip().split('\n')
    questions.append(gensim.utils.simple_preprocess(mecab.parse(cols[0]).strip(), min_len=1))
#     answers.append(cols[1])
# Out:
# --------------------------------------------------------------------------
# FileNotFoundError                        Traceback (most recent call last)
# <ipython-input-5-0132c5a25fb8> in <module>()
#       1 questions = []
#       2 answers = []
# ----> 3 for line in open(args.faq, "r", encoding="utf-8"):
#       4     cols = line.strip().split('\t')
#       5     questions.append(gensim.utils.simple_preprocess(mecab.parse(cols[0]).strip(), min_len=1))
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
doc_vecs = []
for question in questions:
    doc_vecs.append(model.infer_vector(question))

# %%
while True:
    line = input("> ")
    if not line:
        break

    vec = model.infer_vector(gensim.utils.simple_preprocess(mecab.parse(line), min_len=1))
    sims = cosine_similarity([vec], doc_vecs)
    index = np.argsort(sims[0])

    print(questions[index[-1]])
    print()
    print(answers[index[-1]])
    print()

    print(questions[index[-2]])
    print(questions[index[-3]])
    print(questions[index[-4]])
    print()
# Out:
# > aaaa
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-7-622f48d804bb> in <module>()
#       4         break
#       5
# ----> 6     vec = model.infer_vector(gensim.utils.simple_preprocess(mecab.parse(line), min_len=1))
#       7     sims = cosine_similarity([vec], doc_vecs)
#       8     index = np.argsort(sims[0])
#
# NameError: name 'model' is not defined
